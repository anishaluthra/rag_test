# %%
import nest_asyncio

nest_asyncio.apply()

# %%
import qdrant_client

collection_name="chat_with_docs"

client = qdrant_client.QdrantClient(
    host="localhost",
    port=6333
)

# %%
from llama_index.core import SimpleDirectoryReader

input_dir_path = './docs'

loader = SimpleDirectoryReader(
            input_dir = input_dir_path,
            required_exts=[".pdf"],
            recursive=True
        )
docs = loader.load_data()

# %%
from llama_index.vector_stores.qdrant import QdrantVectorStore
from llama_index.core import VectorStoreIndex, ServiceContext, StorageContext

def create_index(documents):

    vector_store = QdrantVectorStore(client=client,
                                     collection_name=collection_name)
    
    storage_context = StorageContext.from_defaults(vector_store=vector_store)
    
    index = VectorStoreIndex.from_documents(documents,
                                            storage_context=storage_context)
    
    return index

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-large-en-v1.5",
                                   trust_remote_code=True)

Settings.embed_model = embed_model

index = create_index(docs)
# Out:
# 2024-12-26 15:37:04.288330: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     142         self._response_closed()
# --> 143 raise exc
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /usr/local/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:106, in ApiClient.send_inner(self, request)
#     105 try:
# --> 106     response = self._client.send(request)
#     107 except Exception as e:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File /usr/local/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ReadTimeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Input In [5], in <cell line: 9>()
#       4 embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-large-en-v1.5",
#       5                                    trust_remote_code=True)
#       7 Settings.embed_model = embed_model
# ----> 9 index = create_index(docs)
#
# Input In [4], in create_index(documents)
#       4 def create_index(documents):
# ----> 6     vector_store = QdrantVectorStore(client=client,
#       7                                      collection_name=collection_name)
#       9     storage_context = StorageContext.from_defaults(vector_store=vector_store)
#      11     index = VectorStoreIndex.from_documents(documents,
#      12                                             storage_context=storage_context)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/vector_stores/qdrant/base.py:200, in QdrantVectorStore.__init__(self, collection_name, client, aclient, url, api_key, batch_size, parallel, max_retries, client_kwargs, dense_config, sparse_config, quantization_config, enable_hybrid, fastembed_sparse_model, sparse_doc_fn, sparse_query_fn, hybrid_fusion_fn, index_doc_id, text_key, **kwargs)
#     197     self._aclient = aclient
#     199 if self._client is not None:
# --> 200     self._collection_initialized = self._collection_exists(collection_name)
#     201 else:
#     202     #  need to do lazy init for async clients
#     203     self._collection_initialized = False
#
# File /usr/local/lib/python3.9/site-packages/llama_index/vector_stores/qdrant/base.py:711, in QdrantVectorStore._collection_exists(self, collection_name)
#     709 def _collection_exists(self, collection_name: str) -> bool:
#     710     """Check if a collection exists."""
# --> 711     return self._client.collection_exists(collection_name)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/qdrant_client.py:2097, in QdrantClient.collection_exists(self, collection_name, **kwargs)
#    2087 """Check whether collection already exists
#    2088
#    2089 Args:
#    (...)
#    2093     True if collection exists, False if not
#    2094 """
#    2095 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2097 return self._client.collection_exists(collection_name=collection_name, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/qdrant_remote.py:2623, in QdrantRemote.collection_exists(self, collection_name, **kwargs)
#    2617 if self._prefer_grpc:
#    2618     return self.grpc_collections.CollectionExists(
#    2619         grpc.CollectionExistsRequest(collection_name=collection_name),
#    2620         timeout=self._timeout,
#    2621     ).result.exists
# -> 2623 result: Optional[models.CollectionExistence] = self.http.collections_api.collection_exists(
#    2624     collection_name=collection_name
#    2625 ).result
#    2626 assert result is not None, "Collection exists returned None"
#    2627 return result.exists
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api/collections_api.py:1157, in SyncCollectionsApi.collection_exists(self, collection_name)
#    1150 def collection_exists(
#    1151     self,
#    1152     collection_name: str,
#    1153 ) -> m.InlineResponse2007:
#    1154     """
#    1155     Returns \"true\" if the given collection name exists, and \"false\" otherwise
#    1156     """
# -> 1157     return self._build_for_collection_exists(
#    1158         collection_name=collection_name,
#    1159     )
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api/collections_api.py:87, in _CollectionsApi._build_for_collection_exists(self, collection_name)
#      82 path_params = {
#      83     "collection_name": str(collection_name),
#      84 }
#      86 headers = {}
# ---> 87 return self.api_client.request(
#      88     type_=m.InlineResponse2007,
#      89     method="GET",
#      90     url="/collections/{collection_name}/exists",
#      91     headers=headers if headers else None,
#      92     path_params=path_params,
#      93 )
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:79, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      77     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      78 request = self._client.build_request(method, url, **kwargs)
# ---> 79 return self.send(request, type_)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:96, in ApiClient.send(self, request, type_)
#      95 def send(self, request: Request, type_: Type[T]) -> T:
# ---> 96     response = self.middleware(request, self.send_inner)
#      97     if response.status_code in [200, 201, 202]:
#      98         try:
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:205, in BaseMiddleware.__call__(self, request, call_next)
#     204 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 205     return call_next(request)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:108, in ApiClient.send_inner(self, request)
#     106     response = self._client.send(request)
#     107 except Exception as e:
# --> 108     raise ResponseHandlingException(e)
#     109 return response
#
# ResponseHandlingException: timed out

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="llama3.2:1b", request_timeout=120.0)

Settings.llm = llm

# %%
from llama_index.core import PromptTemplate

template = """Context information is below:
              ---------------------
              {context_str}
              ---------------------
              Given the context information above I want you to think
              step by step to answer the query in a crisp manner,
              incase you don't know the answer say 'I don't know!'
            
              Query: {query_str}
        
              Answer:"""

qa_prompt_tmpl = PromptTemplate(template)

# %%
from llama_index.core.postprocessor import SentenceTransformerRerank

rerank = SentenceTransformerRerank(
    model="cross-encoder/ms-marco-MiniLM-L-2-v2", 
    top_n=3
)

# %%
query_engine = index.as_query_engine(similarity_top_k=10,
                                     node_postprocessors=[rerank])

query_engine.update_prompts(
    {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
)

response = query_engine.query("What exactly is DSPy?")
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     142         self._response_closed()
# --> 143 raise exc
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /usr/local/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:106, in ApiClient.send_inner(self, request)
#     105 try:
# --> 106     response = self._client.send(request)
#     107 except Exception as e:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File /usr/local/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ReadTimeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Input In [17], in <cell line: 8>()
#       1 query_engine = index.as_query_engine(similarity_top_k=10,
#       2                                      node_postprocessors=[rerank])
#       4 query_engine.update_prompts(
#       5     {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
#       6 )
# ----> 8 response = query_engine.query("What exactly is DSPy?")
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/base/base_query_engine.py:52, in BaseQueryEngine.query(self, str_or_query_bundle)
#      50     if isinstance(str_or_query_bundle, str):
#      51         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52     query_result = self._query(str_or_query_bundle)
#      53 dispatcher.event(
#      54     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      55 )
#      56 return query_result
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/query_engine/retriever_query_engine.py:178, in RetrieverQueryEngine._query(self, query_bundle)
#     174 """Answer a query."""
#     175 with self.callback_manager.event(
#     176     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     177 ) as query_event:
# --> 178     nodes = self.retrieve(query_bundle)
#     179     response = self._response_synthesizer.synthesize(
#     180         query=query_bundle,
#     181         nodes=nodes,
#     182     )
#     183     query_event.on_end(payload={EventPayload.RESPONSE: response})
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/query_engine/retriever_query_engine.py:133, in RetrieverQueryEngine.retrieve(self, query_bundle)
#     132 def retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 133     nodes = self._retriever.retrieve(query_bundle)
#     134     return self._apply_node_postprocessors(nodes, query_bundle=query_bundle)
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/base/base_retriever.py:245, in BaseRetriever.retrieve(self, str_or_query_bundle)
#     240 with self.callback_manager.as_trace("query"):
#     241     with self.callback_manager.event(
#     242         CBEventType.RETRIEVE,
#     243         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     244     ) as retrieve_event:
# --> 245         nodes = self._retrieve(query_bundle)
#     246         nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     247         retrieve_event.on_end(
#     248             payload={EventPayload.NODES: nodes},
#     249         )
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/indices/vector_store/retrievers/retriever.py:103, in VectorIndexRetriever._retrieve(self, query_bundle)
#      97     if query_bundle.embedding is None and len(query_bundle.embedding_strs) > 0:
#      98         query_bundle.embedding = (
#      99             self._embed_model.get_agg_embedding_from_queries(
#     100                 query_bundle.embedding_strs
#     101             )
#     102         )
# --> 103 return self._get_nodes_with_embeddings(query_bundle)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/indices/vector_store/retrievers/retriever.py:180, in VectorIndexRetriever._get_nodes_with_embeddings(self, query_bundle_with_embeddings)
#     176 def _get_nodes_with_embeddings(
#     177     self, query_bundle_with_embeddings: QueryBundle
#     178 ) -> List[NodeWithScore]:
#     179     query = self._build_vector_store_query(query_bundle_with_embeddings)
# --> 180     query_result = self._vector_store.query(query, **self._kwargs)
#     181     return self._build_node_list_from_query_result(query_result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/vector_stores/qdrant/base.py:843, in QdrantVectorStore.query(self, query, **kwargs)
#     841     return self.parse_to_query_result(response[0])
#     842 else:
# --> 843     response = self._client.search(
#     844         collection_name=self.collection_name,
#     845         query_vector=query_embedding,
#     846         limit=query.similarity_top_k,
#     847         query_filter=query_filter,
#     848     )
#     849     return self.parse_to_query_result(response)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/qdrant_client.py:387, in QdrantClient.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     316 """Search for closest vectors in collection taking into account filtering conditions
#     317
#     318 Args:
#    (...)
#     383     List of found close points with similarity scores.
#     384 """
#     385 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# --> 387 return self._client.search(
#     388     collection_name=collection_name,
#     389     query_vector=query_vector,
#     390     query_filter=query_filter,
#     391     search_params=search_params,
#     392     limit=limit,
#     393     offset=offset,
#     394     with_payload=with_payload,
#     395     with_vectors=with_vectors,
#     396     score_threshold=score_threshold,
#     397     append_payload=append_payload,
#     398     consistency=consistency,
#     399     shard_key_selector=shard_key_selector,
#     400     timeout=timeout,
#     401     **kwargs,
#     402 )
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/qdrant_remote.py:563, in QdrantRemote.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     560 if isinstance(with_payload, grpc.WithPayloadSelector):
#     561     with_payload = GrpcToRest.convert_with_payload_selector(with_payload)
# --> 563 search_result = self.http.points_api.search_points(
#     564     collection_name=collection_name,
#     565     consistency=consistency,
#     566     timeout=timeout,
#     567     search_request=models.SearchRequest(
#     568         vector=query_vector,
#     569         filter=query_filter,
#     570         limit=limit,
#     571         offset=offset,
#     572         params=search_params,
#     573         with_vector=with_vectors,
#     574         with_payload=with_payload,
#     575         score_threshold=score_threshold,
#     576         shard_key=shard_key_selector,
#     577     ),
#     578 )
#     579 result: Optional[List[types.ScoredPoint]] = search_result.result
#     580 assert result is not None, "Search returned None"
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api/points_api.py:1820, in SyncPointsApi.search_points(self, collection_name, consistency, timeout, search_request)
#    1810 def search_points(
#    1811     self,
#    1812     collection_name: str,
#    (...)
#    1815     search_request: m.SearchRequest = None,
#    1816 ) -> m.InlineResponse20016:
#    1817     """
#    1818     Retrieve closest points based on vector similarity and given filtering conditions
#    1819     """
# -> 1820     return self._build_for_search_points(
#    1821         collection_name=collection_name,
#    1822         consistency=consistency,
#    1823         timeout=timeout,
#    1824         search_request=search_request,
#    1825     )
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api/points_api.py:852, in _PointsApi._build_for_search_points(self, collection_name, consistency, timeout, search_request)
#     850 if "Content-Type" not in headers:
#     851     headers["Content-Type"] = "application/json"
# --> 852 return self.api_client.request(
#     853     type_=m.InlineResponse20016,
#     854     method="POST",
#     855     url="/collections/{collection_name}/points/search",
#     856     headers=headers if headers else None,
#     857     path_params=path_params,
#     858     params=query_params,
#     859     content=body,
#     860 )
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:79, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      77     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      78 request = self._client.build_request(method, url, **kwargs)
# ---> 79 return self.send(request, type_)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:96, in ApiClient.send(self, request, type_)
#      95 def send(self, request: Request, type_: Type[T]) -> T:
# ---> 96     response = self.middleware(request, self.send_inner)
#      97     if response.status_code in [200, 201, 202]:
#      98         try:
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:205, in BaseMiddleware.__call__(self, request, call_next)
#     204 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 205     return call_next(request)
#
# File /usr/local/lib/python3.9/site-packages/qdrant_client/http/api_client.py:108, in ApiClient.send_inner(self, request)
#     106     response = self._client.send(request)
#     107 except Exception as e:
# --> 108     raise ResponseHandlingException(e)
#     109 return response
#
# ResponseHandlingException: timed out

# %%
from IPython.display import Markdown, display

display(Markdown(str(response)))
# Out:
# DSPy refers to a programming model developed by Stanford Natural Language Processing Group. It allows users to define natural language signatures, which are short declarative specifications of functions that a machine learning (ML) model, such as a transformer-based language model like GPT-3.5, should perform on specific tasks or inputs.
